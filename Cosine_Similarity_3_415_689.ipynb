# %%
# load package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# read article 3 and 415
df_all = pd.read_csv('../input/test2.csv', header = 0, names=["id", "article", "words"])
df_article = pd.concat([df_all[df_all["id"] == 3], df_all[df_all["id"] == 415], df_all[df_all["id"] == 689]], ignore_index=True)
df_article
# Out:
#     id                                            article  \
# 0    3  夏季為斜紋夜盜及甜菜夜蛾發生盛期，請加強注意，及時防治避免損失。 夏日乾燥炎熱的氣候，正是許...
# 1  415  夜蛾拉警報，白粉等著來，臺南區農改場籲請加強防治。臺南區農改場、防檢局及田邊好幫手關心您。 ...
# 2  689  台南區農改場籲請農民注意及時防治斜紋夜盜蟲，提前壓低害蟲密度，以確保作物收成 斜紋夜盜蟲每年...
#
#                                                words
# 0  ['夏季', '斜紋', '夜盜', '甜菜夜蛾', '發生', '盛期', '請', '加...
# 1  ['夜蛾', '拉', '警報', '白粉', '著來', '臺南_區農_改場_籲請', '...
# 2  ['台南_區農', '改場_籲請', '農民_注意', '及時', '防治', '斜紋夜盜蟲...

# %%
# comput tf
vectorizer = CountVectorizer() 
text_count_vector = vectorizer.fit_transform(df_article.words)
tf_vector = text_count_vector.toarray()

print('============全部字詞=============')
print(vectorizer.get_feature_names())
print()
print('==========各文件字詞統計==============')
print(text_count_vector.toarray())
print()
# Out:
# ============全部字詞=============
# ['06', '10', '11_世代', '12', '150', '20', '30', '300', '302', '306', '382', '50', '500', '5912901_轉', '60_公分', 'catid', 'gov', 'http', 'php', 'tndais', 'tw', 'view', 'www', '一天', '一層', '一年', '一期_作', '一條', '三齡', '上並', '上應', '上方', '下位_葉', '下列', '下山', '不足', '中央', '久旱不雨', '之外', '之體', '乾燥', '事項', '二期_作', '交尾', '人稱', '人體', '以後', '作物', '作物_生長點', '作物_種植', '使用', '俗稱', '保持良好', '個點', '倍數', '傍晚', '傷腦筋', '儘速', '光線', '全園_廢耕', '全株', '全身', '兩季', '兩種', '兩面', '公分', '公尺', '公頃', '共同', '共同_防治', '其所', '冷涼', '出現', '初期', '初齡', '利用_性費洛蒙', '劇烈', '加強', '加速', '動作', '包括', '化學_藥劑', '區_農業_改良場_呼籲', '區_農業_改良場_籲請', '區應', '危害', '卵塊', '卵粒', '參考', '參考_植物保護_手冊_推薦', '及時', '受害', '可將', '可於', '可省', '台南_區_農業_改良場', '台南_區農', '各項_作物', '合理_使用', '品質', '啃食', '問題', '噴施', '噴藥_效果', '嚴格遵守_安全_採收期', '嚴重', '嚴重_時', '嚴重危害', '園區', '圓形', '土中', '地區_應採', '均勻_噴施', '場長_指出', '場長_黃山', '增高', '壓低', '壓抑', '夏季', '夏日', '外圍', '多於', '多種', '夜盜', '夜盜蟲', '夜蛾', '夜蛾類', '夜蛾類_害蟲', '大意', '大蒜', '大量', '大量_啃食', '大面積', '天氣', '太陽', '好似', '好發', '嫩葉', '季節', '孵化', '安全', '安全_採收期', '完畢', '宜蘭_地區', '害蟲', '害蟲_密度', '密度', '密集', '寬長', '導致', '小病', '工並', '常見', '幼蟲', '幼蟲_食量', '廠牌', '影響', '影響_光合作用', '影響_產量', '後_浸水', '微生物製劑', '徹底清除', '性費洛蒙', '感染', '應_遵守', '應_選擇', '應立即', '懸掛', '成效', '成蛾', '成蟲', '抗藥性', '持續', '捕殺', '採收', '提前', '提早_落葉', '提高', '損失', '摘除', '擴大', '攀升', '收成', '收成_台南_區_農業', '收成_臺南', '收穫_前', '改場_籲請', '改用', '改良場_籲請', '放置_高度', '效果', '整個', '整地', '數十種', '數百', '斜帶', '斜紋', '斜紋夜盜蟲', '斜紋夜蛾', '方法', '施用', '施藥', '族群_密度', '早晚_溫差', '旱田', '時分', '時常', '時應', '時應_注意', '時應_注意_使用_充足', '時機', '晝伏夜出', '更佳', '最終', '月間', '有效', '期間', '本場_網站', '植株', '植株_心梢', '標示_使用', '機率', '正常_生長', '殺死', '殺蟲', '每年', '每月_更新_誘餌_一次', '毛狀', '毛豆', '氣候', '氣候_乾燥', '氣溫', '水量', '注意', '注意安全_採收期', '活動', '活躍', '混合', '淹死', '淹水', '淺灰', '清園_工作', '清除', '減輕', '滋生', '漸轉', '灰白', '灰綠色', '炎熱', '無害', '物而', '狀況', '玉米', '環境', '甘藷', '甜菜夜蛾', '生長', '產下', '產區', '產品品質', '產生', '產生_抗藥性', '產量', '用藥', '田區', '田菁', '田邊_好幫手', '田間', '病原菌', '病害', '癒合', '登記_藥劑', '發現', '發生', '發病_初期', '白粉', '白粉病', '白至', '白色', '盈丞', '盛期', '監測數據', '目前', '相關', '瞬間', '研究_人員', '確保', '秋季', '種植', '窄域油', '管內', '籲請_農民', '粉狀', '粒之卵', '糖霜', '經濟損失', '綠肥作物', '繁殖', '繁衍', '繼續', '群集_性', '翻犁', '耕田', '聯絡_聯絡人', '臺南_區_農業_改良場', '臺南_區農_改場', '臺南_區農_改場_籲請', '良好', '花卉', '花蓮', '花蓮_區_農業_改良場', '若有', '若遇', '茂密', '茼蒿', '落花生', '葉柄', '葉片', '葉背', '葉菜類', '葉部_病害', '葉面', '著來', '葵無露', '蓮花', '蔓延', '蔡孟旅', '蔬菜', '藉由', '藏匿於', '藥劑', '藥劑_交互', '藥劑_輪流', '蘇力菌', '蟲口_密度', '蟲源', '行政院_農業_委員會_花蓮', '行軍蟲', '表示', '表面', '覆滿', '覆蓋', '許多', '誘殺_雄蟲', '誘蟲', '請_參考_植物保護_手冊', '警報', '變大', '變得', '豌豆', '資料', '趨光性', '距離', '較佳_噴灑', '輕忽', '輪流', '轉換', '農作物', '農友', '農友_注意', '農民_注意', '農�
.69314718 1.69314718
#  1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.28768207 1.69314718 1.69314718 1.69314718 1.28768207 1.69314718
#  1.         1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.28768207 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.28768207 1.28768207 1.69314718 1.69314718 1.69314718
#  1.69314718 1.69314718 1.28768207 1.28768207 1.69314718 1.28768207
#  1.         1.28768207 1.69314718 1.69314718 1.69314718 1.69314718
#  1.28768207 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.28768207 1.28768207 1.28768207 1.         1.69314718 1.28768207
#  1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.28768207 1.69314718 1.69314718 1.69314718 1.28768207
#  1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.69314718 1.69314718 1.28768207 1.69314718 1.69314718
#  1.69314718 1.         1.69314718 1.28768207 1.69314718 1.69314718
#  1.28768207 1.69314718 1.         1.28768207 1.69314718 1.28768207
#  1.28768207 1.69314718 1.69314718 1.         1.69314718 1.69314718
#  1.28768207 1.69314718 1.69314718 1.28768207 1.69314718 1.69314718
#  1.69314718 1.28768207 1.28768207 1.69314718 1.         1.69314718
#  1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.69314718
#  1.69314718 1.28768207 1.69314718 1.69314718 1.69314718 1.69314718]
#
# ============TFIDF============
#               0         1         2
# 06     0.000000  0.051980  0.000000
# 10     0.000000  0.039532  0.099679
# 11_世代  0.000000  0.000000  0.065533
# 12     0.000000  0.000000  0.065533
# 150    0.000000  0.051980  0.000000
# ...         ...       ...       ...
# 黑肚蟲    0.051582  0.000000  0.049840
# 黑色     0.000000  0.000000  0.065533
# 黑蟲     0.000000  0.000000  0.065533
# 黑褐色    0.000000  0.000000  0.065533
# 點選     0.000000  0.051980  0.000000
#
# [408 rows x 3 columns]

# %%
print('============關鍵字萃取============')
for i, vector in enumerate(docs_tfidf.toarray()):
    doc_tfidf = list(zip(vectorizer.get_feature_names(), vector))
    doc_tfidf = sorted(doc_tfidf, key=lambda x: x[1], reverse=True)
    top3_keywords = [x[0] for x in doc_tfidf[:3]]
    print('doc' + str(i+1) + ": " + '、'.join(top3_keywords))
# Out:
# ============關鍵字萃取============
# doc1: 甜菜夜蛾、懸掛、降低
# doc2: 白粉病、作物、防治
# doc3: 作物、斜紋夜盜蟲、幼蟲

# %%
docs = df_article.to_numpy()
docs[0][2]
# Out:
# "['夏季', '斜紋', '夜盜', '甜菜夜蛾', '發生', '盛期', '請', '加強', '注意', '及時', '防治', '避免', '損失', '夏日', '乾燥', '炎熱', '氣候', '許多', '農作物', '害蟲', '好發', '時機', '花蓮_區_農業_改良場', '籲請_農民', '注意', '斜紋', '夜盜', '甜菜夜蛾', '防治', '造成', '作物', '損失', '氣溫', '增高', '許多', '農作物', '害蟲', '隨之', '變得', '活躍', '監測數據', '顯示', '宜蘭_地區', '出現', '夜蛾類_害蟲', '高峰', '包括', '斜紋夜蛾', '甜菜夜蛾', '斜紋夜蛾', '人稱', '黑肚蟲', '食性', '綠', '吃', '種植', '蔬菜', '農友', '傷腦筋', '害蟲', '青蔥', '產區', '斜紋夜蛾', '之外', '甜菜夜蛾', '危害', '孵化', '幼蟲', '藏匿於', '蔥', '管內', '啃食', '青蔥', '炎熱', '天氣', '加速', '兩種', '害蟲', '繁衍', '減輕', '其所', '造成', '嚴重', '經濟損失', '行政院_農業_委員會_花蓮', '區_農業_改良場_呼籲', '花蓮', '宜蘭_地區', '農友', '持續', '進行', '防治_工作', '輕忽', '大意', '大量', '誘殺_雄蟲', '懸掛', '性費洛蒙', '誘蟲', '盒', '園區', '外圍', '藉由', '大量', '誘殺_雄蟲', '降低', '雌蟲', '交尾', '機率', '族群_密度', '壓抑', '懸掛', '距離', '20', '50', '公尺', '大面積', '共同', '懸掛', '效果', '更佳', '摘除', '卵塊', '發現', '葉背', '毛狀', '卵塊', '摘除', '葉片', '動作', '瞬間', '清除', '300', '500', '顆', '孵化', '卵粒', '蘇力菌', '防治', '幼蟲', '輪流', '噴施', '廠牌', '蘇力菌', '降低', '幼蟲', '密度', '蘇力菌', '有效', '殺死', '初齡', '夜蛾', '幼蟲', '環境', '安全', '微生物製劑', '人體', '無害', '蘇力菌', '殺蟲', '農藥', '混合', '施用', '可省', '工並', '降低', '抗藥性', '發生', '合理_使用', '農藥', '防治', '夜蛾', '藥劑', '應', '參考_植物保護_手冊_推薦', '藥劑_輪流', '施用', '兩種', '藥劑', '避免_抗藥性', '產生', '應_遵守', '安全_採收期', '施用', '倍數', '使用', '方法', '避免', '造成', '農藥_殘留']"

# %% [markdown]
# Actual Results
# - 3 -> 415
# - 689 -> 415

# %%
print('============TF + 餘弦相似度============')
# Results
print('文本：3, 415   TF + 餘弦相似度：', cosine_similarity([tf_vector[0]], [tf_vector[1]]))
print('文本：3, 689   TF + 餘弦相似度：', cosine_similarity([tf_vector[0]], [tf_vector[2]]))
print('文本：415, 689 TF + 餘弦相似度：', cosine_similarity([tf_vector[1]], [tf_vector[2]]))
print('文本：689, 415 TF + 餘弦相似度：', cosine_similarity([tf_vector[2]], [tf_vector[1]]))
# Out:
# ============TF + 餘弦相似度============
# 文本：3, 415   TF + 餘弦相似度： [[0.3380617]]
# 文本：3, 689   TF + 餘弦相似度： [[0.29349018]]
# 文本：415, 689 TF + 餘弦相似度： [[0.57525848]]
# 文本：689, 415 TF + 餘弦相似度： [[0.57525848]]

# %%
print('============TF-IDF + 餘弦相似度============')
# Results
print('文本：3, 415   TF-IDF + 餘弦相似度：', cosine_similarity([df[0]], [df[1]]))
print('文本：3, 689   TF-IDF + 餘弦相似度：', cosine_similarity([df[0]], [df[2]]))
print('文本：415, 689 TF-IDF + 餘弦相似度：', cosine_similarity([df[1]], [df[2]]))
print('文本：689, 415 TF-IDF + 餘弦相似度：', cosine_similarity([df[2]], [df[1]]))
# Out:
# ============TF-IDF + 餘弦相似度============
# 文本：3, 415   TF-IDF + 餘弦相似度： [[0.21108354]]
# 文本：3, 689   TF-IDF + 餘弦相似度： [[0.17296192]]
# 文本：415, 689 TF-IDF + 餘弦相似度： [[0.3971169]]
# 文本：689, 415 TF-IDF + 餘弦相似度： [[0.3971169]]

# %%
# End of file
